# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.environ.get('GROQ_API_KEY'),
    base_url="https://api.groq.com/openai/v1",
)

# %%
response = client.responses.create(
    input='Whats the best way to actually be a good programmer in the age of AI-assisted coding if I am still in the learning phase ? ',
    model= 'llama-3.3-70b-versatile'
)

print(response.output_text)
# Out:
# Response(id='resp_01ky8hqsh1fa8sw357fs622mez', created_at=1784845952.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='llama-3.3-70b-versatile', object='response', output=[ResponseReasoningItem(id='resp_01ky8hqsh1fa99d7q17nam6dew', summary=[], type='reasoning', content=None, encrypted_content=None, status='completed'), ResponseOutputMessage(id='msg_01ky8hqsh1fa9vcv638anhspnv', content=[ResponseOutputText(annotations=[], text="As a learner in the age of AI-assisted coding, it's excellent that you're thinking about how to develop strong programming skills. Here are some tips to help you become a good programmer while navigating the benefits and limitations of AI-assisted coding tools:\n\n**Focus on fundamentals**\n\n1. **Understand the basics**: Make sure you have a solid grasp of programming concepts, data structures, algorithms, and software design patterns.\n2. **Learn by doing**: Practice writing code by hand, without relying on AI-assisted tools. This will help you develop problem-solving skills and a deeper understanding of coding principles.\n3. **Develop problem-solving skills**: Focus on breaking down complex problems into manageable parts, identifying patterns, and applying logical thinking.\n\n**Use AI-assisted tools strategically**\n\n1. **Use code completion and suggestions**: AI-assisted tools like code completion and suggestions can help you learn new syntax and APIs.\n2. **Analyze and learn from generated code**: Use AI-generated code as a starting point, but take the time to understand how it works and how you can improve it.\n3. **Avoid over-reliance**: Don't rely solely on AI-assisted tools to write code. Use them to augment your learning, but also focus on writing code yourself.\n\n**Develop soft skills**\n\n1. **Read and understand code**: Learn to read and understand code written by others, including open-source projects and coding challenges.\n2. **Debugging and testing**: Develop skills in debugging and testing, which are essential for writing robust and reliable code.\n3. **Communication and teamwork**: Practice explaining your code and ideas to others, and learn to work collaboratively on coding projects.\n\n**Stay up-to-date with industry trends**\n\n1. **Follow industry leaders and blogs**: Stay current with the latest developments in programming languages, frameworks, and technologies.\n2. ** Participate in coding communities**: Join online forums, social media groups, and coding communities to learn from others and get feedback on your work.\n3. **Attend workshops and conferences**: Attend workshops, conferences, and meetups to learn from experts and network with other programmers.\n\n**Set realistic goals and track progress**\n\n1. **Set achievable goals**: Set specific, measurable, and attainable goals for your learning journey.\n2. **Track your progress**: Keep a journal or log to track your progress, reflect on what you've learned, and identify areas for improvement.\n3. **Be patient and persistent**: Learning to program takes time and effort. Stay motivated, and don't be afraid to make mistakes – they're an essential part of the learning process.\n\n**Additional tips**\n\n1. **Use online resources**: Leverage online resources like tutorials, videos, and coding challenges to supplement your learning.\n2. **Find a mentor**: Seek guidance from experienced programmers who can provide valuable feedback and support.\n3. **Join online coding challenges**: Participate in coding challenges and hackathons to practice your skills and learn from others.\n\nBy following these tips, you'll be well on your way to becoming a skilled programmer in the age of AI-assisted coding. Remember to stay curious, keep learning, and have fun!", type='output_text', logprobs=None)], role='assistant', status='completed', type='message', phase=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=None, conversation=None, max_outp ...
